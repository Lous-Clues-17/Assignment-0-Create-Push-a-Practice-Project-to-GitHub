# %% [markdown]
# # About Me
# I’m a bilingual professional driven by a simple question: What’s the story behind the data? By blending my background in human behavior with data analytics, I aim to uncover the 'why' behind the numbers. Looking forward to all the learning we'll do together!

# %%
print("Hello, Data Science Cohort!")
# Out:
# Hello, Data Science Cohort!
